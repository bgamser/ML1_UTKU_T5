# %%
print("Hey Team !!")
# Out:
# Hey Team !!

# %%
# %%ai ollama:qwen2.5-coder:7b
# I have a file called 'titanic.csv'.
# Please write the code to:
# 1. Load the data using pandas.
# 2. Show the first 5 rows.
# 3. Tell me which columns have missing values.
# Out:
# UsageError: Cell magic `%%ai` not found.
